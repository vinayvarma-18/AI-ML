# %% [markdown]
# # CSE-221710308039-VINAY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
# Loading the dataset from sklearn
from sklearn.datasets import load_boston
boston=load_boston()
df=pd.DataFrame(data=boston.data, columns=boston.feature_names)
df['MEDV']=boston.target
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Visualize all the input columns with the output column.Write your observations based on the plots generated, how the particular input is showing effect on the output

sns.regplot(df.CRIM,df.MEDV)#CRIM

# %% [markdown]
# #### According to the above plot, the input CRIM has weakly negative correlation with the output MEDV.
# #### So, it has very minimal effect on the output.

# %%
sns.regplot(df.ZN,df.MEDV) #ZN

# %% [markdown]
# #### According to the above plot, the input ZN has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.INDUS,df.MEDV) #INDUS

# %% [markdown]
# #### According to the above plot, the input INDUS has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.CHAS,df.MEDV) #CHAS

# %% [markdown]
# #### According to the above plot, the input CHAS has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.NOX,df.MEDV) #NOX

# %% [markdown]
# #### According to the above plot, the input NOX has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.RM,df.MEDV) #RM

# %% [markdown]
# #### According to the above plot, the input RM has moderately negative correlation with the output MEDV.
# #### So, it has moderate effect on the output.

# %%
sns.regplot(df.AGE,df.MEDV) #AGE

# %% [markdown]
# #### According to the above plot, the input AGE has weakly negative correlation with the output MEDV.
# #### So, it has little effect on the output.

# %%
sns.regplot(df.DIS,df.MEDV) #DIS

# %% [markdown]
# #### According to the above plot, the input DIS has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.RAD,df.MEDV) #RAD

# %% [markdown]
# #### According to the above plot, the input RAD has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.TAX,df.MEDV) #TAX

# %% [markdown]
# #### According to the above plot, the input TAX has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.PTRATIO,df.MEDV) #PTRATIO

# %% [markdown]
# #### According to the above plot, the input PTRATIO has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.B,df.MEDV) #B

# %% [markdown]
# #### According to the above plot, the input B has no correlation with the output MEDV.
# #### So, it has no effect on the output.

# %%
sns.regplot(df.LSTAT,df.MEDV) #LSTAT

# %% [markdown]
# #### According to the above plot, the input LSTAT has moderately negative correlation with the output MEDV.
# #### So, it has moderate effect on the output.

# %%
#Remove any of the one variable from the dataset if correlation is greater than 0.9. 
df.corr()[df.corr()>0.9]
# Out:
#          CRIM   ZN  INDUS  CHAS  NOX   RM  AGE  DIS       RAD       TAX  \
# CRIM      1.0  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# ZN        NaN  1.0    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# INDUS     NaN  NaN    1.0   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# CHAS      NaN  NaN    NaN   1.0  NaN  NaN  NaN  NaN       NaN       NaN
# NOX       NaN  NaN    NaN   NaN  1.0  NaN  NaN  NaN       NaN       NaN
# RM        NaN  NaN    NaN   NaN  NaN  1.0  NaN  NaN       NaN       NaN
# AGE       NaN  NaN    NaN   NaN  NaN  NaN  1.0  NaN       NaN       NaN
# DIS       NaN  NaN    NaN   NaN  NaN  NaN  NaN  1.0       NaN       NaN
# RAD       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  1.000000  0.910228
# TAX       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  0.910228  1.000000
# PTRATIO   NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# B         NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# LSTAT     NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# MEDV      NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
#
#          PTRATIO    B  LSTAT  MEDV
# CRIM         NaN  NaN    NaN   NaN
# ZN           NaN  NaN    NaN   NaN
# INDUS        NaN  NaN    NaN   NaN
# CHAS         NaN  NaN    NaN   NaN
# NOX          NaN  NaN    NaN   NaN
# RM           NaN  NaN    NaN   NaN
# AGE          NaN  NaN    NaN   NaN
# DIS          NaN  NaN    NaN   NaN
# RAD          NaN  NaN    NaN   NaN
# TAX          NaN  NaN    NaN   NaN
# PTRATIO      1.0  NaN    NaN   NaN
# B            NaN  1.0    NaN   NaN
# LSTAT        NaN  NaN    1.0   NaN
# MEDV         NaN  NaN    NaN   1.0

# %%
df.drop('RAD',axis=1,inplace=True) #dropping RAD column
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS    TAX  PTRATIO  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  296.0     15.3
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  242.0     17.8
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  242.0     17.8
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  222.0     18.7
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  222.0     18.7
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  222.0     18.7
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  311.0     15.2
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  311.0     15.2
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  311.0     15.2
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  311.0     15.2
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467  311.0     15.2
# 11    0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267  311.0     15.2
# 12    0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509  311.0     15.2
# 13    0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075  307.0     21.0
# 14    0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619  307.0     21.0
# 15    0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986  307.0     21.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986  307.0     21.0
# 17    0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579  307.0     21.0
# 18    0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965  307.0     21.0
# 19    0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965  307.0     21.0
# 20    1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979  307.0     21.0
# 21    0.85204   0.0   8.14   0.0  0.538  5.965   89.2  4.0123  307.0     21.0
# 22    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769  307.0     21.0
# 23    0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952  307.0     21.0
# 24    0.75026   0.0   8.14   0.0  0.538  5.924   94.1  4.3996  307.0     21.0
# 25    0.84054   0.0   8.14   0.0  0.538  5.599   85.7  4.4546  307.0     21.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813   90.3  4.6820  307.0     21.0
# 27    0.95577   0.0   8.14   0.0  0.538  6.047   88.8  4.4534  307.0     21.0
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547  307.0     21.0
# 29    1.00245   0.0   8.14   0.0  0.538  6.674   87.3  4.2390  307.0     21.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...    ...      ...
# 476   4.87141   0.0  18.10   0.0  0.614  6.484   93.6  2.3053  666.0     20.2
# 477  15.02340   0.0  18.10   0.0  0.614  5.304   97.3  2.1007  666.0     20.2
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705  666.0     20.2
# 479  14.33370   0.0  18.10   0.0  0.614  6.229   88.0  1.9512  666.0     20.2
# 480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  666.0     20.2
# 481   5.70818   0.0  18.10   0.0  0.532  6.750   74.9  3.3317  666.0     20.2
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  666.0     20.2
# 483   2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  666.0     20.2
# 484   2.37857   0.0  18.10   0.0  0.583  5.871   41.9  3.7240  666.0     20.2
# 485   3.67367   0.0  18.10   0.0  0.583  6.312   51.9  3.9917  666.0     20.2
# 486   5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5459  666.0     20.2
# 487   4.83567   0.0  18.10   0.0  0.583  5.905   53.2  3.1523  666.0     20.2
# 488   0.15086   0.0  27.74   0.0  0.609  5.454   92.7  1.8209  711.0     20.1
# 489   0.18337   0.0  27.74   0.0  0.609  5.414   98.3  1.7554  711.0     20.1
# 490   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226  711.0     20.1
# 491   0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681  711.0     20.1
# 492   0.11132   0.0  27.74   0.0  0.609  5.983   83.5  2.1099  711.0     20.1
# 493   0.17331   0.0   9.69   0.0  0.585  5.707   54.0  2.3817  391.0     19.2
# 494   0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817  391.0     19.2
# 495   0.17899   0.0   9.69   0.0  0.585  5.670   28.8  2.7986  391.0     19.2
# 496   0.28960   0.0   9.69   0.0  0.585  5.390   72.9  2.7986  391.0     19.2
# 497   0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927  391.0     19.2
# 498   0.23912   0.0   9.69   0.0  0.585  6.019   65.3  2.4091  391.0     19.2
# 499   0.17783   0.0   9.69   0.0  0.585  5.569   73.5  2.3999  391.0     19.2
# 500   0.22438   0.0   9.69   0.0  0.585  6.027   79.7  2.4982  391.0     19.2
# 501   0.06263   0.0  11.93   0.0  0.573  6.593   69.1  2.4786  273.0     21.0
# 502   0.04527   0.0  11.93   0.0  0.573  6.120   76.7  2.2875  273.0     21.0
# 503   0.06076   0.0  11.93   0.0  0.573  6.976   91.0  2.1675  273.0     21.0
# 504   0.10959   0.0  11.93   0.0  0.573  6.794   89.3  2.3889  273.0     21.0
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   80.8  2.5050  273.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# 5    394.12   5.21  28.7
# 6    395.60  12.43  22.9
# 7    396.90  19.15  27.1
# 8    386.63  29.93  16.5
# 9    386.71  17.10  18.9
# 10   392.52  20.45  15.0
# 11   396.90  13.27  18.9
# 12   390.50  15.71  21.7
# 13   396.90   8.26  20.4
# 14   380.02  10.26  18.2
# 15   395.62   8.47  19.9
# 16   386.85   6.58  23.1
# 17   386.75  14.67  17.5
# 18   288.99  11.69  20.2
# 19   390.95  11.28  18.2
# 20   376.57  21.02  13.6
# 21   392.53  13.83  19.6
# 22   396.90  18.72  15.2
# 23   394.54  19.88  14.5
# 24   394.33  16.30  15.6
# 25   303.42  16.51  13.9
# 26   376.88  14.81  16.6
# 27   306.38  17.28  14.8
# 28   387.94  12.80  18.4
# 29   380.23  11.98  21.0
# ..      ...    ...   ...
# 476  396.21  18.68  16.7
# 477  349.48  24.91  12.0
# 478  379.70  18.03  14.6
# 479  383.32  13.11  21.4
# 480  396.90  10.74  23.0
# 481  393.07   7.74  23.7
# 482  395.28   7.01  25.0
# 483  392.92  10.42  21.8
# 484  370.73  13.34  20.6
# 485  388.62  10.58  21.2
# 486  392.68  14.98  19.1
# 487  388.22  11.45  20.6
# 488  395.09  18.06  15.2
# 489  344.05  23.97   7.0
# 490  318.43  29.68   8.1
# 491  390.11  18.07  13.6
# 492  396.90  13.35  20.1
# 493  396.90  12.01  21.8
# 494  396.90  13.59  24.5
# 495  393.29  17.60  23.1
# 496  396.90  21.14  19.7
# 497  396.90  14.10  18.3
# 498  396.90  12.92  21.2
# 499  395.77  15.10  17.5
# 500  396.90  14.33  16.8
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %%
#Split the data into training and test with a split ratio of 80-20
#(80% of the data into training data and 20% of the data into testing)
from sklearn.model_selection import train_test_split
X=df.drop(['MEDV'],axis=1)
y=df.MEDV
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
print('X_train: ',X_train.shape)
print('X_test: ',X_test.shape)
print('y_train: ',y_train.shape)
print('y_test: ',y_test.shape)
# Out:
# X_train:  (404, 12)
# X_test:  (102, 12)
# y_train:  (404,)
# y_test:  (102,)

# %%
#Apply feature scaling on the input columns, and build the Multiple Linear Regression Model. 
#Check the performance on training and testing. 
#Write your inferences on performance metrics and error metrics.
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_scaled=pd.DataFrame(data=sc.fit_transform(df),columns=df.columns)
df_scaled
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# 5   -0.417044 -0.487722 -1.306878 -0.272599 -0.835284  0.207096 -0.351157
# 6   -0.410243  0.048772 -0.476654 -0.272599 -0.265154 -0.388411 -0.070229
# 7   -0.403696  0.048772 -0.476654 -0.272599 -0.265154 -0.160466  0.978808
# 8   -0.395935  0.048772 -0.476654 -0.272599 -0.265154 -0.931206  1.117494
# 9   -0.400729  0.048772 -0.476654 -0.272599 -0.265154 -0.399808  0.616090
# 10  -0.394346  0.048772 -0.476654 -0.272599 -0.265154  0.131589  0.914799
# 11  -0.406847  0.048772 -0.476654 -0.272599 -0.265154 -0.392685  0.509409
# 12  -0.409604  0.048772 -0.476654 -0.272599 -0.265154 -0.563644 -1.051700
# 13  -0.347230 -0.487722 -0.437258 -0.272599 -0.144217 -0.478164 -0.240919
# 14  -0.346276 -0.487722 -0.437258 -0.272599 -0.144217 -0.268740  0.566306
# 15  -0.347506 -0.487722 -0.437258 -0.272599 -0.144217 -0.642000 -0.429390
# 16  -0.297868 -0.487722 -0.437258 -0.272599 -0.144217 -0.498110 -1.396638
# 17  -0.329258 -0.487722 -0.437258 -0.272599 -0.144217 -0.419753  0.466736
# 18  -0.327103 -0.487722 -0.437258 -0.272599 -0.144217 -1.180521 -1.137046
# 19  -0.336054 -0.487722 -0.437258 -0.272599 -0.144217 -0.794439  0.032897
# 20  -0.274843 -0.487722 -0.437258 -0.272599 -0.144217 -1.018110  1.049929
# 21  -0.321363 -0.487722 -0.437258 -0.272599 -0.144217 -0.455370  0.733440
# 22  -0.277091 -0.487722 -0.437258 -0.272599 -0.144217 -0.203205  0.822342
# 23  -0.305491 -0.487722 -0.437258 -0.272599 -0.144217 -0.671918  1.117494
# 24  -0.333207 -0.487722 -0.437258 -0.272599 -0.144217 -0.513781  0.907687
# 25  -0.322701 -0.487722 -0.437258 -0.272599 -0.144217 -0.976795  0.608978
# 26  -0.342325 -0.487722 -0.437258 -0.272599 -0.144217 -0.671918  0.772557
# 27  -0.309291 -0.487722 -0.437258 -0.272599 -0.144217 -0.338548  0.719216
# 28  -0.330562 -0.487722 -0.437258 -0.272599 -0.144217  0.299699  0.918355
# 29  -0.303859 -0.487722 -0.437258 -0.272599 -0.144217  0.554713  0.665875
# ..        ...       ...       ...       ...       ...       ...       ...
# 476  0.146384 -0.487722  1.015999 -0.272599  0.512296  0.284028  0.889907
# 477  1.327804 -0.487722  1.015999 -0.272599  0.512296 -1.397069  1.021481
# 478  0.770330 -0.487722  1.015999 -0.272599  0.512296 -0.141945  1.000145
# 479  1.247542 -0.487722  1.015999 -0.272599  0.512296 -0.079260  0.690768
# 480  0.257241 -0.487722  1.015999 -0.272599 -0.196047 -0.060739 -0.137794
# 481  0.243762 -0.487722  1.015999 -0.272599 -0.196047  0.662987  0.224924
# 482  0.246436 -0.487722  1.015999 -0.272599 -0.196047  1.106056  0.299601
# 483 -0.092533 -0.487722  1.015999 -0.272599 -0.196047 -0.744576 -1.005472
# 484 -0.143716 -0.487722  1.015999 -0.272599  0.244507 -0.589288 -0.948575
# 485  0.006999 -0.487722  1.015999 -0.272599  0.244507  0.038987 -0.592969
# 486  0.241850 -0.487722  1.015999 -0.272599  0.244507 -0.243096  0.399171
# 487  0.142225 -0.487722  1.015999 -0.272599  0.244507 -0.540849 -0.546740
# 488 -0.402961 -0.487722  2.422565 -0.272599  0.469104 -1.183370  0.857902
# 489 -0.399178 -0.487722  2.422565 -0.272599  0.469104 -1.240357  1.057042
# 490 -0.396375 -0.487722  2.422565 -0.272599  0.469104 -1.697672  1.046373
# 491 -0.408212 -0.487722  2.422565 -0.272599  0.469104 -0.429726  1.074822
# 492 -0.407563 -0.487722  2.422565 -0.272599  0.469104 -0.429726  0.530745
# 493 -0.400349 -0.487722 -0.211099 -0.272599  0.261784 -0.822932 -0.518292
# 494 -0.387983 -0.487722 -0.211099 -0.272599  0.261784 -0.510932 -0.923682
# 495 -0.399688 -0.487722 -0.211099 -0.272599  0.261784 -0.875644 -1.414418
# 496 -0.386816 -0.487722 -0.211099 -0.272599  0.261784 -1.274549  0.153803
# 497 -0.389285 -0.487722 -0.211099 -0.272599  0.261784 -0.698987  0.072014
# 498 -0.392690 -0.487722 -0.211099 -0.272599  0.261784 -0.378438 -0.116457
# 499 -0.399823 -0.487722 -0.211099 -0.272599  0.261784 -1.019535  0.175139
# 500 -0.394406 -0.487722 -0.211099 -0.272599  0.261784 -0.367041  0.395615
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       TAX   PTRATIO         B     LSTAT      MEDV
# 0    0.140214 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1    0.557160 -0.987329 -0.303094  0.441052 -0.492439 -0.101524
# 2    0.557160 -0.987329 -0.303094  0.396427 -1.208727  1.324247
# 3    1.077737 -1.106115  0.113032  0.416163 -1.361517  1.182758
# 4    1.077737 -1.106115  0.113032  0.441052 -1.026501  1.487503
# 5    1.077737 -1.106115  0.113032  0.410571 -1.043322  0.671222
# 6    0.839244 -0.577519 -1.505237  0.426798 -0.031268  0.039964
# 7    1.024638 -0.577519 -1.505237  0.441052  0.910700  0.497082
# 8    1.087196 -0.577519 -1.505237  0.328448  2.421774 -0.656595
# 9    1.329635 -0.577519 -1.505237  0.329325  0.623344 -0.395385
# 10   1.212979 -0.577519 -1.505237  0.393028  1.092926 -0.819852
# 11   1.155935 -0.577519 -1.505237  0.441052  0.086478 -0.395385
# 12   0.787143 -0.577519 -1.505237  0.370880  0.428502 -0.090641
# 13   0.433754 -0.601276  1.176466  0.441052 -0.615792 -0.232129
# 14   0.317003 -0.601276  1.176466  0.255974 -0.335445 -0.471572
# 15   0.334449 -0.601276  1.176466  0.427018 -0.586356 -0.286548
# 16   0.334449 -0.601276  1.176466  0.330860 -0.851284  0.061732
# 17   0.220028 -0.601276  1.176466  0.329764  0.282722 -0.547758
# 18   0.000693 -0.601276  1.176466 -0.742112 -0.134996 -0.253897
# 19   0.000693 -0.601276  1.176466  0.375814 -0.192467 -0.471572
# 20   0.001358 -0.601276  1.176466  0.218147  1.172825 -0.972224
# 21   0.103277 -0.601276  1.176466  0.393138  0.164976 -0.319199
# 22   0.086449 -0.601276  1.176466  0.441052  0.850425 -0.798084
# 23   0.142686 -0.601276  1.176466  0.415176  1.013027 -0.874270
# 24   0.287388 -0.601276  1.176466  0.412874  0.511205 -0.754549
# 25   0.313533 -0.601276  1.176466 -0.583896  0.540641 -0.939573
# 26   0.421632 -0.601276  1.176466  0.221545  0.302346 -0.645712
# 27   0.312963 -0.601276  1.176466 -0.551442  0.648575 -0.841619
# 28   0.313581 -0.601276  1.176466  0.342811  0.020597 -0.449804
# 29   0.211044 -0.601276  1.176466  0.258276 -0.094346 -0.166827
# ..        ...       ...       ...       ...       ...       ...
# 476 -0.708178  1.530926  0.806576  0.433487  0.844819 -0.634828
# 477 -0.805438  1.530926  0.806576 -0.078878  1.718101 -1.146364
# 478 -0.772257  1.530926  0.806576  0.252465  0.753706 -0.863387
# 479 -0.876506  1.530926  0.806576  0.292156  0.064051 -0.123292
# 480 -0.176287  1.530926  0.806576  0.441052 -0.268161  0.050848
# 481 -0.220259  1.530926  0.806576  0.399058 -0.688683  0.127034
# 482 -0.182752  1.530926  0.806576  0.423290 -0.791010  0.268523
# 483  0.144159  1.530926  0.806576  0.397414 -0.313017 -0.079757
# 484 -0.033772  1.530926  0.806576  0.154115  0.096291 -0.210362
# 485  0.093485  1.530926  0.806576  0.350267 -0.290589 -0.145059
# 486 -0.118435  1.530926  0.806576  0.394782  0.326176 -0.373618
# 487 -0.305540  1.530926  0.806576  0.345881 -0.168638 -0.210362
# 488 -0.938447  1.798194  0.760340  0.421206  0.757911 -0.798084
# 489 -0.969583  1.798194  0.760340 -0.138414  1.586338 -1.690551
# 490 -0.937638  1.798194  0.760340 -0.419321  2.386730 -1.570830
# 491 -0.916009  1.798194  0.760340  0.366604  0.759313 -0.972224
# 492 -0.801065  1.798194  0.760340  0.441052  0.097692 -0.264781
# 493 -0.671859 -0.102376  0.344213  0.441052 -0.090141 -0.079757
# 494 -0.671859 -0.102376  0.344213  0.441052  0.131334  0.214104
# 495 -0.473678 -0.102376  0.344213  0.401471  0.693431  0.061732
# 496 -0.473678 -0.102376  0.344213  0.441052  1.189646 -0.308315
# 497 -0.428946 -0.102376  0.344213  0.441052  0.202823 -0.460688
# 498 -0.658834 -0.102376  0.344213  0.441052  0.037418 -0.145059
# 499 -0.663208 -0.102376  0.344213  0.428662  0.342996 -0.547758
# 500 -0.616479 -0.102376  0.344213  0.441052  0.235063 -0.623944
# 501 -0.625796 -0.803212  1.176466  0.387217 -0.418147 -0.014454
# 502 -0.716639 -0.803212  1.176466  0.441052 -0.500850 -0.210362
# 503 -0.773684 -0.803212  1.176466  0.441052 -0.983048  0.148802
# 504 -0.668437 -0.803212  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.803212  1.176466  0.441052 -0.669058 -1.157248
#
# [506 rows x 13 columns]

# %%
#build the Multiple Linear Regression Model.
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)

# %%
y_train_pred
# Out:
# array([25.61389622, 24.42859951, 21.38401926, 25.14444135, 24.73192216,
#        29.77165132, 38.12520125, 31.27114849, 22.99435611, 36.99568018,
#        24.07789266, 21.74542523, 30.99781623, 27.71759792, 28.67033271,
#        31.38156653, 26.50501372, 29.26514731, 16.76013888, 20.18998114,
#        21.63931657, 36.07483823, 25.04508184, 22.15246868, 15.46191931,
#         5.13355119, 14.68789546, 22.81066641, 26.95969431, 35.17983187,
#        22.53876804, 21.40544126, 24.92483205, 25.54816329, 29.80546871,
#        26.31002247, 35.30769323, 22.54181577, 13.57103079, 37.96034266,
#        32.36183293, 17.09608457, 24.79504138, 19.78353673, 20.06926989,
#        24.90464222, 25.24990602, 29.35116939, 17.26536883, 16.38864418,
#        41.75973289, 34.80744486, 21.16053828, 21.6667248 , 22.2741087 ,
#        12.15451453, 22.38564192, 25.05519789, 20.71477732, 27.88278591,
#        43.37319603, 24.10334084, 25.59559056, 20.46381238, 17.83701731,
#        31.25681412, 17.64110007, 12.18824102, 18.64754763, 32.70753227,
#        36.60716443, 21.28660251,  0.64545339, 17.59976867, 27.83899956,
#        18.38322487, 27.62364611, 24.7879974 , 25.9538304 , 19.88620275,
#        23.16521699, 40.5025283 , 26.74787675, 38.70388947, 24.00762794,
#        15.60725634, 21.08785   , 18.20565107, 25.25334053, 34.88598023,
#        10.06782541, 21.34822582, 19.58610181, 27.47097003, 25.52181537,
#        17.54825032, 21.67721295, 33.5265809 , 18.37344424, 23.16774921,
#        27.66064397, 26.70332703, 17.98391835, 16.91269102, 16.51509394,
#        16.07037261, 29.29944062, 19.2795765 , 18.22486146, 14.781021  ,
#        31.94353819, 17.3781326 , 21.2243288 , 21.5257235 , 34.03655432,
#        18.04262521, 32.6646365 , 16.37834296,  9.34920499, -3.84071637,
#        21.59701513,  9.80977254, 26.82275095, 28.88476781, 22.19021255,
#        26.56642559, 24.06376657, 16.83609715, 14.4276967 , 26.84869587,
#        26.26693497, 12.3039164 , 23.19782252, 25.47947245,  8.55824999,
#        14.0763401 , 26.47639511, 22.1240526 , 33.61365282, 24.01798526,
#        19.67189769, 12.52140762, 21.4882023 , 19.35402795, 16.39856186,
#        25.48868022, 42.10126668, 19.23776655, 18.80876558,  9.09705254,
#        24.59616149, 32.85962448, 17.18157386, 34.0308436 , 23.76236038,
#        19.0200339 , 34.10027567, 15.73814495, 18.10928893, 33.22271616,
#        17.56688861, 12.43199232, 24.74280769, 11.60793882, 27.62156286,
#        27.84552168, 26.76325532, 28.69855193, 23.7055855 , 22.92399583,
#        21.95590821, 21.14509853, 23.20821914, 22.64150386, 14.24207449,
#        24.61361373, 24.3591545 , 14.79480416, 27.02373974, 21.76085115,
#         6.60112631, 11.79072477, 27.22546307, 18.86472151, 13.84090511,
#        13.66090331, 21.88103635, 16.11499534, 16.8050575 , 21.25835598,
#        15.96970349, 22.96514481, 23.60013817,  4.75617454, 20.08310723,
#        16.00323721,  7.02032306, 16.14817432, 24.69182445, 22.05890891,
#        21.57927912, 31.2429616 , 19.82073743, 28.31866166, 35.77294178,
#        25.41376504, 32.04638134, 13.17515868, 17.38046162, 37.92967   ,
#        24.66617157, 15.46221655, 15.69751442, 18.90986174, 23.6513588 ,
#         4.42034671, 18.42694932, 24.86943621, 31.48571077, 20.42535495,
#        24.49949266,  8.84287127, 28.80411317, 14.78743921, 21.08271121,
#        21.16973098, 30.89368083, 16.8531598 , 16.66986625, 36.14874981,
#        17.47040211, 22.7820101 , 15.26446   , 31.87163118, 21.4581642 ,
#        14.70650566, 20.42026627, 17.42217394, 38.05577639, 30.72815651,
#        36.92277409, 27.78736429, 29.10989826, 19.5504831 , 23.3901106 ,
#        22.11859511, 19.60929362, 15.20938535,  7.56118078, 34.37759678,
#        37.44896429, 30.60904124, 26.71720181, 13.52451984, 27.63763785,
#        15.79481022, 21.18234011, 16.30634835, 22.48540508, 23.78420257,
#        25.72491005, 13.94505046, 27.17727039, 28.90041312, 18.35453814,
#        15.17818449, 17.55591833, 31.34760123, 20.00497264, 25.51591956,
#        23.99565247, 23.98498641, 13.88765262, 17.96726386, 15.47200279,
#        27.41918204, 12.85000217, 21.04544405, 19.41844653, 21.40257058,
#        37.1965516 , 16.89707683, 43.67351347, 15.1610442 , 23.00559239,
#        21.47696171, 14.20965339, 18.16246921, 12.63693334, 40.87913132,
#        19.90507329, 12.49267457, 32.6068129 , 23.88939197, 19.74096942,
#        32.04750504, 20.4842489 , 26.0156076 , 28.64822448, 20.10397408,
#        21.35815825, 17.7966597 , 19.63085355, 27.69011178, 18.7225772 ,
#        20.49511809, 11.14681993,  5.16435031, 28.57450189, 20.98362548,
#        10.26189172, 30.49597449, 16.80468522, 25.83406221, 19.56923868,
#        39.82064776, 15.65321834, 24.80339143, 17.76276965, 16.83255483,
#        35.73487095, 17.99432377, 17.99653012, 11.55983779, 15.07417151,
#        18.75564434, 30.83468364, 17.74460725, 14.2680782 , 21.39132863,
#        23.06451622, 40.48832767, 20.73313339, 36.06909991, 14.96047271,
#        17.22366318, 24.26901718, 30.84297304, 30.37242596, 10.01813074,
#        16.70365903, 19.01097822, 17.57606044, 18.8354867 , 26.20197907,
#        27.53103309, 23.13075724, 21.25289512, 12.52756999, 15.03306003,
#        16.09696462, 18.41784551, 21.2876855 , 31.51851878, 33.11703127,
#        24.49467801, 22.61211545, 35.09183705, 27.43477307, 12.86006935,
#        19.2298223 ,  2.19568857, 28.13814748, 21.68967817, 28.62770053,
#        23.27547   , 17.2261646 , 12.21825421, 32.97691205, 23.85798119,
#        22.79224366, 22.12088378,  8.93932161, 19.52869462, 18.15223059,
#        11.31499895, 24.0310675 , 17.27361926, 27.65125393, 20.38416663,
#        15.9318486 , 22.01073565, 10.2426218 , 18.42871788, 24.90842096,
#        21.81851085, 33.73379666, 32.93980959, 17.26390077, 12.16431907,
#        13.93808682, 24.60990477, 21.72693709, 33.8967967 , 19.40469681,
#        19.45925214, 17.5886208 , 24.50396526, 25.42336838, 21.45610083,
#        23.64280883, 18.29669394, 20.54579096, 21.95590935])

# %%
#Checking the performance on both using r2_score and Adjusted r2_score:
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('Train :')

print('R^2:', r2_score(y_train,y_train_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_train, y_train_pred))*(len(X_train)-1)/
      (len(X_train)-X_train.shape[1]-1))
print('MAE: ',mean_absolute_error(y_train,y_train_pred))
print('MSE: ',mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_train,y_train_pred)))

print('Test :')

print('R^2:', r2_score(y_test,y_test_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_test, y_test_pred))*(len(X_test)-1)/
      (len(X_test)-X_test.shape[1]-1))
print('MAE: ',mean_absolute_error(y_test,y_test_pred))
print('MSE ',mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# Train :
# R^2: 0.741356512845881
# Adjusted R^2: 0.7334186053117393
# MAE:  3.1002663679411566
# MSE:  19.97179736834396
# RMSE:  4.468981692549653
# Test :
# R^2: 0.690069730178007
# Adjusted R^2: 0.648281379190772
# MAE:  4.105273583683694
# MSE  34.77144785097753
# RMSE:  5.896731963636937

# %% [markdown]
# ###  Performance Metrics:
#
# #### Training:
#     -R2: it indicates 74% accuracy
#     -adjusted R2: indicates 73% accuracy
# #### Testing:
#     -The RMSE is 4.46, indicating an error of +/- 4.6 in the predicted values
#     -The accuracy of the model on predicting the trained data is around 73% and the error caused while
#     predicting these values is around 4.46
#
# ###  Error Metrics:
#
# #### Training:
#     -R2: it indicates 69% accuracy
#     -adjusted R2: indicates 64% accuracy
# #### Testing:
#     -The RMSE is 5.86, indicating an error of +/- 5.86 in the predicted values
#     -The accuracy of the model on predicting the trained data is around 69% and the error caused while
#     predicting these values is around 5.8
