# %% [markdown]
# # CSE-221710308039-VINAY

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ig=plt.imread("indian.jpg")
print(ig.shape)
# Out:
# (300, 400, 3)

# %%
plt.imshow(ig)

# %%
plt.imshow(ig[:,:,0])

# %%
plt.imshow(ig[:,:,0],cmap='RdPu')

# %%
plt.imshow(ig[:,0:100])#cricket player

# %%
plt.imshow(ig[:400,:400])

# %%
plt.imshow(ig[85:400,105:165]) #jersey

# %%
plt.imshow(ig[250:,:500]) #shoes
